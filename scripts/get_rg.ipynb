# %% [markdown]
# <a href="https://colab.research.google.com/github/chandlersutherland/e12/blob/main/get_rg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# GATK requires read group information, so this script is to pull it out of the metadata file provided by Wang Long. The syntax required is
#
# @RG\tID:{flowcell_ID}.{lane_number}\tPL:ILLUMINA\tPU:{flowcell_ID}.{lane_number}.{library}\tSM:{acession}\tLB:{library}
#
# Singletons (libraries that were only run once) are processed first, then duplicates (libraries that had to be run twice). This is an artifact of me thinking the duplicates already had read groups, but also makes the file name finding easier since the singletons are named by accession and the duplicates are named by lane info.

# %%
import os 
import pandas as pd

# %%
#import file_names document 
metadata = pd.read_excel('/content/drive/MyDrive/Krasileva_Lab/colab_projects/inputs/Col_64_leaves.sequencing_lanes_raw.xlsx')
metadata.rename(columns={'Unnamed: 0':'accession', 'Sample_ID':'library_ID'}, inplace=True)
metadata

#unpack lane info into separate columns 
lane_info = pd.DataFrame()
lane_info[['instrument', 'run_number', 'flowcell_barcode', 'lane_number', 'tile']] = metadata['Lane_info'].str.split(':', expand=True)
metadata = metadata.merge(lane_info, left_index=True, right_index=True).drop(['Lane_info'], axis=1)
metadata

#add accession info based on library id 
file_names = pd.read_excel('/content/drive/MyDrive/Krasileva_Lab/colab_projects/inputs/file names.xlsx')
fn = file_names[['accession', 'library_ID']]
md = fn.merge(metadata, how='inner').sort_values('accession')

# %% [markdown]
# ##Singletons

# %%
singletons = md[['accession', 'library_ID', 'Lane_ID', 'flowcell_barcode', 'lane_number', 'tile']].drop_duplicates(subset = 'accession', keep = False).reset_index(drop = True)

# %%
#test out the syntax 

#@RG\tID:{flowcell_ID}.{lane_number}\tPL:ILLUMINA\tPU:{flowcell_ID}.{lane_number}.{library}\tSM:{accession}\tLB:{library}
accession = singletons.loc[0,'accession']
library = singletons.loc[0,'library_ID']
flowcell_ID = singletons.loc[0,'flowcell_barcode']
lane_number = singletons.loc[0,'lane_number']
print("@RG\\tID:" + str(flowcell_ID) + "." + str(lane_number) + "\\tPL:ILLUMINA\\tPU:" + str(flowcell_ID) + "." + str(lane_number) + "." + str(library) + "\\tSM:" + str(accession) + "\\tLB" + str(library))
# Out:
# @RG\tID:HC2TWBBXX.6\tPL:ILLUMINA\tPU:HC2TWBBXX.6.Col24_SL5-1\tSM:SRR8367186\tLBCol24_SL5-1

# %%
#now, write a for loop to output this information into a csv file for adding to samtools files 
filename = "singleton_rg.tsv"
in_dir = "/content/drive/MyDrive/Krasileva_Lab/colab_projects/outputs/"
fh = open(in_dir + filename, 'w')

for i in range(0, len(singletons)):
  accession = singletons.loc[i,'accession']
  library = singletons.loc[i,'library_ID']
  flowcell_ID = singletons.loc[i,'flowcell_barcode']
  lane_number = singletons.loc[i,'lane_number']
  fh.write(str(accession) + '\t' + "'@RG\\tID:" + str(flowcell_ID) + "." + str(lane_number) + "\\tPL:ILLUMINA\\tPU:" + str(flowcell_ID) + "." + str(lane_number) + "." + str(library) + "\\tSM:" + str(accession) + "\\tLB:" + str(library) +"'"+'\n')

fh.close()

# %%
#check my work 
newfh = open(in_dir + filename, 'r')
for line in newfh: 
  print(line)
# Out:
# SRR8367186	'@RG\tID:HC2TWBBXX.6\tPL:ILLUMINA\tPU:HC2TWBBXX.6.Col24_SL5-1\tSM:SRR8367186\tLB:Col24_SL5-1'
#
# SRR8367191	'@RG\tID:HC2TWBBXX.1\tPL:ILLUMINA\tPU:HC2TWBBXX.1.Col17_SL4-2\tSM:SRR8367191\tLB:Col17_SL4-2'
#
# SRR8367201	'@RG\tID:HC2TWBBXX.6\tPL:ILLUMINA\tPU:HC2TWBBXX.6.Col24_SL7-2\tSM:SRR8367201\tLB:Col24_SL7-2'
#
# SRR8367203	'@RG\tID:HC2TWBBXX.6\tPL:ILLUMINA\tPU:HC2TWBBXX.6.Col24_SL3-3\tSM:SRR8367203\tLB:Col24_SL3-3'
#
# SRR8367204	'@RG\tID:HC2TWBBXX.6\tPL:ILLUMINA\tPU:HC2TWBBXX.6.Col24_SL4-1\tSM:SRR8367204\tLB:Col24_SL4-1'
#
# SRR8367205	'@RG\tID:HC2TWBBXX.6\tPL:ILLUMINA\tPU:HC2TWBBXX.6.Col24_SL4-2\tSM:SRR8367205\tLB:Col24_SL4-2'
#
# SRR8367206	'@RG\tID:HC2TWBBXX.6\tPL:ILLUMINA\tPU:HC2TWBBXX.6.Col24_SL4-3\tSM:SRR8367206\tLB:Col24_SL4-3'
#
# SRR8367208	'@RG\tID:HC2TWBBXX.6\tPL:ILLUMINA\tPU:HC2TWBBXX.6.Col24_SL5-2\tSM:SRR8367208\tLB:Col24_SL5-2'
#
# SRR8367209	'@RG\tID:HC2TWBBXX.6\tPL:ILLUMINA\tPU:HC2TWBBXX.6.Col24_SL5-3\tSM:SRR8367209\tLB:Col24_SL5-3'
#
# SRR8367210	'@RG\tID:HC2TWBBXX.6\tPL:ILLUMINA\tPU:HC2TWBBXX.6.Col24_SL6-2\tSM:SRR8367210\tLB:Col24_SL6-2'
#
# SRR8367223	'@RG\tID:HC2TWBBXX.6\tPL:ILLUMINA\tPU:HC2TWBBXX.6.Col24_SL7-1\tSM:SRR8367223\tLB:Col24_SL7-1'
#
# SRR8367224	'@RG\tID:HC2TWBBXX.6\tPL:ILLUMINA\tPU:HC2TWBBXX.6.Col24_SL9-2\tSM:SRR8367224\tLB:Col24_SL9-2'
#
# SRR8367226	'@RG\tID:HC2TWBBXX.1\tPL:ILLUMINA\tPU:HC2TWBBXX.1.Col17_SL8-2\tSM:SRR8367226\tLB:Col17_SL8-2'
#
# SRR8367227	'@RG\tID:HC2TWBBXX.1\tPL:ILLUMINA\tPU:HC2TWBBXX.1.Col17_SL5-1\tSM:SRR8367227\tLB:Col17_SL5-1'
#
# SRR8367228	'@RG\tID:HC2TWBBXX.1\tPL:ILLUMINA\tPU:HC2TWBBXX.1.Col17_SL4-3\tSM:SRR8367228\tLB:Col17_SL4-3'
#
# SRR8367229	'@RG\tID:HC2TWBBXX.1\tPL:ILLUMINA\tPU:HC2TWBBXX.1.Col17_SL6-1\tSM:SRR8367229\tLB:Col17_SL6-1'
#
# SRR8367230	'@RG\tID:HC2TWBBXX.1\tPL:ILLUMINA\tPU:HC2TWBBXX.1.Col17_SL5-3\tSM:SRR8367230\tLB:Col17_SL5-3'
#
# SRR8367231	'@RG\tID:HC2TWBBXX.1\tPL:ILLUMINA\tPU:HC2TWBBXX.1.Col17_SL7-1\tSM:SRR8367231\tLB:Col17_SL7-1'
#
# SRR8367232	'@RG\tID:HC2TWBBXX.1\tPL:ILLUMINA\tPU:HC2TWBBXX.1.Col17_SL6-2\tSM:SRR8367232\tLB:Col17_SL6-2'
#
# SRR8367233	'@RG\tID:HC2TWBBXX.1\tPL:ILLUMINA\tPU:HC2TWBBXX.1.Col17_SL8-1\tSM:SRR8367233\tLB:Col17_SL8-1'
#
# SRR8367234	'@RG\tID:HC2TWBBXX.1\tPL:ILLUMINA\tPU:HC2TWBBXX.1.Col17_SL7-2\tSM:SRR8367234\tLB:Col17_SL7-2'
#
# SRR8367235	'@RG\tID:HC2TWBBXX.6\tPL:ILLUMINA\tPU:HC2TWBBXX.6.Col24_SL8-3\tSM:SRR8367235\tLB:Col24_SL8-3'
#
# SRR8367236	'@RG\tID:HC2TWBBXX.6\tPL:ILLUMINA\tPU:HC2TWBBXX.6.Col24_SL8-2\tSM:SRR8367236\tLB:Col24_SL8-2'
#
# SRR8367237	'@RG\tID:HC2TWBBXX.6\tPL:ILLUMINA\tPU:HC2TWBBXX.6.Col24_SL3-2\tSM:SRR8367237\tLB:Col24_SL3-2'
#
# SRR8367238	'@RG\tID:HC2TWBBXX.6\tPL:ILLUMINA\tPU:HC2TWBBXX.6.Col24_SL3-1\tSM:SRR8367238\tLB:Col24_SL3-1'
#
# SRR8367239	'@RG\tID:HC2TWBBXX.1\tPL:ILLUMINA\tPU:HC2TWBBXX.1.Col24_SL2-3\tSM:SRR8367239\tLB:Col24_SL2-3'
#
# SRR8367240	'@RG\tID:HC2TWBBXX.1\tPL:ILLUMINA\tPU:HC2TWBBXX.1.Col24_SL2-2\tSM:SRR8367240\tLB:Col24_SL2-2'
#
# SRR8367241	'@RG\tID:HC2TWBBXX.1\tPL:ILLUMINA\tPU:HC2TWBBXX.1.Col24_SL2-1\tSM:SRR8367241\tLB:Col24_SL2-1'
#
# SRR8367242	'@RG\tID:HC2TWBBXX.1\tPL:ILLUMINA\tPU:HC2TWBBXX.1.Col24_SL1-3\tSM:SRR8367242\tLB:Col24_SL1-3'
#
# SRR8367243	'@RG\tID:HC2TWBBXX.1\tPL:ILLUMINA\tPU:HC2TWBBXX.1.Col24_SL1-2\tSM:SRR8367243\tLB:Col24_SL1-2'
#
# SRR8367244	'@RG\tID:HC2TWBBXX.1\tPL:ILLUMINA\tPU:HC2TWBBXX.1.Col24_SL1-1\tSM:SRR8367244\tLB:Col24_SL1-1'
#
# SRR8367247	'@RG\tID:HC2TWBBXX.6\tPL:ILLUMINA\tPU:HC2TWBBXX.6.Col24_SL9-1\tSM:SRR8367247\tLB:Col24_SL9-1'

# %% [markdown]
# ##Read group Files

# %%
#first, have to tidy the filenames file by putting the filenames in the same column

#read in file names document, subset to accession, library ID, and filenames 
fn2 = file_names[['accession', 'library_ID', 'filename', 'filename2', 'filename3', 'filename4']]

#make a dataframe of only the libraries that were run twice by grabbing filename 3 and 4, dropping nas, and making this filename and filename2 
double_runs = fn2[['accession', 'library_ID', 'filename3', 'filename4']].dropna().rename(columns = {'filename3':'filename', 'filename4':'filename2'})
double_runs

#grab the single runs/first run for double 
single_runs = fn2[['accession', 'library_ID', 'filename', 'filename2']]
single_runs

#merge together, creating two rows per accession if the library had to be run twice. Change filename format as appropriate 
together = double_runs.append(single_runs).sort_values('accession')[['accession', 'library_ID', 'filename']]
together['filename'] = together['filename'].str.replace('_1.fq.gz', '.bam')

#add a flowcell barcode so I can merge with the original metadata file 
together['flowcell_barcode'] = together['filename'].str.lstrip("FC").str[:-23].str.rstrip("_")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   app.launch_new_instance()

# %%
#merge together to create a dataframe with accession, all the RG info, and the filename
all_names = md.merge(together, on=['accession', 'library_ID', 'flowcell_barcode'])

#filter by duplicate values, since all the singletons already have rgs added 
duplicate_names = all_names[-all_names.accession.isin(singletons.accession)].reset_index(drop = True) 
duplicate_names
# Out:
#      accession   library_ID DNA_ID Lane_ID   Barcode  Read_Pairs   GC%  \
# 0   SRR8367185  Col24_RL2-1  24_21   Lane6  TAATGTTG    11861549  41.0
# 1   SRR8367185  Col24_RL2-1  24_21   Lane4  TAATGTTG    10841218  41.0
# 2   SRR8367187  Col24_RL2-3  24_23   Lane6  GTTACTTG    13635592  39.0
# 3   SRR8367187  Col24_RL2-3  24_23   Lane4  GTTACTTG    10731726  38.0
# 4   SRR8367188  Col24_RL4-2  24_42   Lane4  CTTGATGG    13980544  40.0
# ..         ...          ...    ...     ...       ...         ...   ...
# 59  SRR8367245  Col24_RL5-3  24_53   Lane4  TATTCGCG    11921918  41.0
# 60  SRR8367246  Col24_RL5-1  24_51   Lane4  CTAAGTCG    12077593  40.0
# 61  SRR8367246  Col24_RL5-1  24_51   Lane6  CTAAGTCG    15110008  40.0
# 62  SRR8367248  Col17_RL4-1  17_41   Lane6  CTAGTTAT     8056094  39.0
# 63  SRR8367248  Col17_RL4-1  17_41   Lane5  CTAGTTAT     8932525  39.0
#
#     Raw_Data(G)  Raw_Depth instrument run_number flowcell_barcode lane_number  \
# 0      3.558465  29.653872     K00137        295        HC2V5BBXX           2
# 1      3.252365  27.103045     K00137        285        H7NHMBBXX           1
# 2      4.090678  34.088980     K00137        295        HC2V5BBXX           2
# 3      3.219518  26.829315     K00137        285        H7NHMBBXX           1
# 4      4.194163  34.951360     K00137        285        H7NHMBBXX           1
# ..          ...        ...        ...        ...              ...         ...
# 59     3.576575  29.804795     K00137        285        H7NHMBBXX           1
# 60     3.623278  30.193983     K00137        285        H7NHMBBXX           1
# 61     4.533002  37.775020     K00137        295        HC2V5BBXX           2
# 62     2.416828  20.140235     K00137        295        HC2V5BBXX           2
# 63     2.679758  22.331313     K00137        285        H7NHMBBXX           2
#
#     tile                            filename
# 0   1101  FCHC2V5BBXX_L2_wHAXPI032499-26.bam
# 1   1101  FCH7NHMBBXX_L1_wHAXPI032499-26.bam
# 2   1101  FCHC2V5BBXX_L2_wHAXPI032500-27.bam
# 3   1101  FCH7NHMBBXX_L1_wHAXPI032500-27.bam
# 4   1103  FCH7NHMBBXX_L1_wHAXPI032505-32.bam
# ..   ...                                 ...
# 59  1104  FCH7NHMBBXX_L1_wHAXPI032508-36.bam
# 60  1104  FCH7NHMBBXX_L1_wHAXPI032507-35.bam
# 61  1103  FCHC2V5BBXX_L2_wHAXPI032507-35.bam
# 62  1106  FCHC2V5BBXX_L2_wHAXPI032445-20.bam
# 63  1101  FCH7NHMBBXX_L2_wHAXPI032445-20.bam
#
# [64 rows x 15 columns]

# %%
#write accession, filename, and rg info to duplicate_names.tsv

filename = "duplicate_names.tsv"
in_dir = "/content/drive/MyDrive/Krasileva_Lab/colab_projects/outputs/"
fh = open(in_dir + filename, 'w')

for i in range(0, len(duplicate_names)):
  accession = duplicate_names.iloc[i,0]
  library = duplicate_names.loc[i,'library_ID']
  flowcell_ID = duplicate_names.loc[i,'flowcell_barcode']
  lane_number = duplicate_names.loc[i,'lane_number']
  fn = duplicate_names.loc[i, 'filename']
  fh.write(str(accession) + '\t' + 
           str(fn) + '\t' +
           "'@RG\\tID:" + str(flowcell_ID) + "." + str(lane_number) + 
           "\\tPL:ILLUMINA\\tPU:" + str(flowcell_ID) + "." + str(lane_number) + "." + str(library) + 
           "\\tSM:" + str(accession) + "\\tLB:" + str(library) +"'"+'\n')
fh.close()

newfh = open(in_dir + filename, 'r')
for line in newfh: 
  print(line)
# Out:
# SRR8367185	FCHC2V5BBXX_L2_wHAXPI032499-26.bam	'@RG\tID:HC2V5BBXX.2\tPL:ILLUMINA\tPU:HC2V5BBXX.2.Col24_RL2-1\tSM:SRR8367185\tLB:Col24_RL2-1'
#
# SRR8367185	FCH7NHMBBXX_L1_wHAXPI032499-26.bam	'@RG\tID:H7NHMBBXX.1\tPL:ILLUMINA\tPU:H7NHMBBXX.1.Col24_RL2-1\tSM:SRR8367185\tLB:Col24_RL2-1'
#
# SRR8367187	FCHC2V5BBXX_L2_wHAXPI032500-27.bam	'@RG\tID:HC2V5BBXX.2\tPL:ILLUMINA\tPU:HC2V5BBXX.2.Col24_RL2-3\tSM:SRR8367187\tLB:Col24_RL2-3'
#
# SRR8367187	FCH7NHMBBXX_L1_wHAXPI032500-27.bam	'@RG\tID:H7NHMBBXX.1\tPL:ILLUMINA\tPU:H7NHMBBXX.1.Col24_RL2-3\tSM:SRR8367187\tLB:Col24_RL2-3'
#
# SRR8367188	FCH7NHMBBXX_L1_wHAXPI032505-32.bam	'@RG\tID:H7NHMBBXX.1\tPL:ILLUMINA\tPU:H7NHMBBXX.1.Col24_RL4-2\tSM:SRR8367188\tLB:Col24_RL4-2'
#
# SRR8367188	FCHC2V5BBXX_L2_wHAXPI032505-32.bam	'@RG\tID:HC2V5BBXX.2\tPL:ILLUMINA\tPU:HC2V5BBXX.2.Col24_RL4-2\tSM:SRR8367188\tLB:Col24_RL4-2'
#
# SRR8367189	FCH7NHMBBXX_L1_wHAXPI032506-34.bam	'@RG\tID:H7NHMBBXX.1\tPL:ILLUMINA\tPU:H7NHMBBXX.1.Col24_RL4-3\tSM:SRR8367189\tLB:Col24_RL4-3'
#
# SRR8367189	FCHC2V5BBXX_L2_wHAXPI032506-34.bam	'@RG\tID:HC2V5BBXX.2\tPL:ILLUMINA\tPU:HC2V5BBXX.2.Col24_RL4-3\tSM:SRR8367189\tLB:Col24_RL4-3'
#
# SRR8367190	FCH7NHMBBXX_L1_wHAXPI032567-19.bam	'@RG\tID:H7NHMBBXX.1\tPL:ILLUMINA\tPU:H7NHMBBXX.1.Col17_SL4-1\tSM:SRR8367190\tLB:Col17_SL4-1'
#
# SRR8367190	FCHCFN7BBXX_L4_wHAXPI032567-19.bam	'@RG\tID:HCFN7BBXX.4\tPL:ILLUMINA\tPU:HCFN7BBXX.4.Col17_SL4-1\tSM:SRR8367190\tLB:Col17_SL4-1'
#
# SRR8367192	FCHC2V5BBXX_L2_wHAXPI032516-40.bam	'@RG\tID:HC2V5BBXX.2\tPL:ILLUMINA\tPU:HC2V5BBXX.2.Col17_SL2-3\tSM:SRR8367192\tLB:Col17_SL2-3'
#
# SRR8367192	FCH7NHMBBXX_L1_wHAXPI032516-40.bam	'@RG\tID:H7NHMBBXX.1\tPL:ILLUMINA\tPU:H7NHMBBXX.1.Col17_SL2-3\tSM:SRR8367192\tLB:Col17_SL2-3'
#
# SRR8367193	FCHC2V5BBXX_L2_wHAXPI032517-41.bam	'@RG\tID:HC2V5BBXX.2\tPL:ILLUMINA\tPU:HC2V5BBXX.2.Col17_SL3-1\tSM:SRR8367193\tLB:Col17_SL3-1'
#
# SRR8367193	FCH7NHMBBXX_L1_wHAXPI032517-41.bam	'@RG\tID:H7NHMBBXX.1\tPL:ILLUMINA\tPU:H7NHMBBXX.1.Col17_SL3-1\tSM:SRR8367193\tLB:Col17_SL3-1'
#
# SRR8367194	FCH7NHMBBXX_L1_wHAXPI032518-42.bam	'@RG\tID:H7NHMBBXX.1\tPL:ILLUMINA\tPU:H7NHMBBXX.1.Col17_SL3-2\tSM:SRR8367194\tLB:Col17_SL3-2'
#
# SRR8367194	FCHC2V5BBXX_L2_wHAXPI032518-42.bam	'@RG\tID:HC2V5BBXX.2\tPL:ILLUMINA\tPU:HC2V5BBXX.2.Col17_SL3-2\tSM:SRR8367194\tLB:Col17_SL3-2'
#
# SRR8367195	FCH7NHMBBXX_L1_wHAXPI032519-45.bam	'@RG\tID:H7NHMBBXX.1\tPL:ILLUMINA\tPU:H7NHMBBXX.1.Col17_SL3-3\tSM:SRR8367195\tLB:Col17_SL3-3'
#
# SRR8367195	FCHC2V5BBXX_L2_wHAXPI032519-45.bam	'@RG\tID:HC2V5BBXX.2\tPL:ILLUMINA\tPU:HC2V5BBXX.2.Col17_SL3-3\tSM:SRR8367195\tLB:Col17_SL3-3'
#
# SRR8367196	FCHCFN7BBXX_L4_wHAXPI032512-34.bam	'@RG\tID:HCFN7BBXX.4\tPL:ILLUMINA\tPU:HCFN7BBXX.4.Col17_SL1-2\tSM:SRR8367196\tLB:Col17_SL1-2'
#
# SRR8367196	FCH7NHMBBXX_L2_wHAXPI032512-34.bam	'@RG\tID:H7NHMBBXX.2\tPL:ILLUMINA\tPU:H7NHMBBXX.2.Col17_SL1-2\tSM:SRR8367196\tLB:Col17_SL1-2'
#
# SRR8367197	FCHCFN7BBXX_L4_wHAXPI032513-35.bam	'@RG\tID:HCFN7BBXX.4\tPL:ILLUMINA\tPU:HCFN7BBXX.4.Col17_SL1-3\tSM:SRR8367197\tLB:Col17_SL1-3'
#
# SRR8367197	FCH7NHMBBXX_L2_wHAXPI032513-35.bam	'@RG\tID:H7NHMBBXX.2\tPL:ILLUMINA\tPU:H7NHMBBXX.2.Col17_SL1-3\tSM:SRR8367197\tLB:Col17_SL1-3'
#
# SRR8367198	FCHCFN7BBXX_L4_wHAXPI032514-36.bam	'@RG\tID:HCFN7BBXX.4\tPL:ILLUMINA\tPU:HCFN7BBXX.4.Col17_SL2-1\tSM:SRR8367198\tLB:Col17_SL2-1'
#
# SRR8367198	FCH7NHMBBXX_L2_wHAXPI032514-36.bam	'@RG\tID:H7NHMBBXX.2\tPL:ILLUMINA\tPU:H7NHMBBXX.2.Col17_SL2-1\tSM:SRR8367198\tLB:Col17_SL2-1'
#
# SRR8367199	FCH7NHMBBXX_L1_wHAXPI032515-39.bam	'@RG\tID:H7NHMBBXX.1\tPL:ILLUMINA\tPU:H7NHMBBXX.1.Col17_SL2-2\tSM:SRR8367199\tLB:Col17_SL2-2'
#
# SRR8367199	FCHC2V5BBXX_L2_wHAXPI032515-39.bam	'@RG\tID:HC2V5BBXX.2\tPL:ILLUMINA\tPU:HC2V5BBXX.2.Col17_SL2-2\tSM:SRR8367199\tLB:Col17_SL2-2'
#
# SRR8367200	FCHC2V5BBXX_L2_wHAXPI032497-24.bam	'@RG\tID:HC2V5BBXX.2\tPL:ILLUMINA\tPU:HC2V5BBXX.2.Col24_RL1-2\tSM:SRR8367200\tLB:Col24_RL1-2'
#
# SRR8367200	FCH7NHMBBXX_L2_wHAXPI032497-24.bam	'@RG\tID:H7NHMBBXX.2\tPL:ILLUMINA\tPU:H7NHMBBXX.2.Col24_RL1-2\tSM:SRR8367200\tLB:Col24_RL1-2'
#
# SRR8367202	FCH7NHMBBXX_L2_wHAXPI032498-25.bam	'@RG\tID:H7NHMBBXX.2\tPL:ILLUMINA\tPU:H7NHMBBXX.2.Col24_RL1-3\tSM:SRR8367202\tLB:Col24_RL1-3'
#
# SRR8367202	FCHC2V5BBXX_L2_wHAXPI032498-25.bam	'@RG\tID:HC2V5BBXX.2\tPL:ILLUMINA\tPU:HC2V5BBXX.2.Col24_RL1-3\tSM:SRR8367202\tLB:Col24_RL1-3'
#
# SRR8367207	FCHC2V5BBXX_L2_wHAXPI032503-30.bam	'@RG\tID:HC2V5BBXX.2\tPL:ILLUMINA\tPU:HC2V5BBXX.2.Col24_RL3-3\tSM:SRR8367207\tLB:Col24_RL3-3'
#
# SRR8367207	FCH7NHMBBXX_L1_wHAXPI032503-30.bam	'@RG\tID:H7NHMBBXX.1\tPL:ILLUMINA\tPU:H7NHMBBXX.1.Col24_RL3-3\tSM:SRR8367207\tLB:Col24_RL3-3'
#
# SRR8367211	FCHC2V5BBXX_L2_wHAXPI032495-22.bam	'@RG\tID:HC2V5BBXX.2\tPL:ILLUMINA\tPU:HC2V5BBXX.2.Col17_RL4-3\tSM:SRR8367211\tLB:Col17_RL4-3'
#
# SRR8367211	FCH7NHMBBXX_L2_wHAXPI032495-22.bam	'@RG\tID:H7NHMBBXX.2\tPL:ILLUMINA\tPU:H7NHMBBXX.2.Col17_RL4-3\tSM:SRR8367211\tLB:Col17_RL4-3'
#
# SRR8367212	FCH7NHMBBXX_L2_wHAXPI032511-32.bam	'@RG\tID:H7NHMBBXX.2\tPL:ILLUMINA\tPU:H7NHMBBXX.2.Col17_SL1-1\tSM:SRR8367212\tLB:Col17_SL1-1'
#
# SRR8367212	FCHCFN7BBXX_L4_wHAXPI032511-32.bam	'@RG\tID:HCFN7BBXX.4\tPL:ILLUMINA\tPU:HCFN7BBXX.4.Col17_SL1-1\tSM:SRR8367212\tLB:Col17_SL1-1'
#
# SRR8367213	FCHC2V5BBXX_L2_wHAXPI032504-31.bam	'@RG\tID:HC2V5BBXX.2\tPL:ILLUMINA\tPU:HC2V5BBXX.2.Col24_RL4-1\tSM:SRR8367213\tLB:Col24_RL4-1'
#
# SRR8367213	FCH7NHMBBXX_L1_wHAXPI032504-31.bam	'@RG\tID:H7NHMBBXX.1\tPL:ILLUMINA\tPU:H7NHMBBXX.1.Col24_RL4-1\tSM:SRR8367213\tLB:Col24_RL4-1'
#
# SRR8367214	FCH7NHMBBXX_L1_wHAXPI032501-28.bam	'@RG\tID:H7NHMBBXX.1\tPL:ILLUMINA\tPU:H7NHMBBXX.1.Col24_RL3-1\tSM:SRR8367214\tLB:Col24_RL3-1'
#
# SRR8367214	FCHC2V5BBXX_L2_wHAXPI032501-28.bam	'@RG\tID:HC2V5BBXX.2\tPL:ILLUMINA\tPU:HC2V5BBXX.2.Col24_RL3-1\tSM:SRR8367214\tLB:Col24_RL3-1'
#
# SRR8367215	FCHC2V5BBXX_L2_wHAXPI032439-13.bam	'@RG\tID:HC2V5BBXX.2\tPL:ILLUMINA\tPU:HC2V5BBXX.2.Col17_RL1-1\tSM:SRR8367215\tLB:Col17_RL1-1'
#
# SRR8367215	FCH7NHMBBXX_L2_wHAXPI032439-13.bam	'@RG\tID:H7NHMBBXX.2\tPL:ILLUMINA\tPU:H7NHMBBXX.2.Col17_RL1-1\tSM:SRR8367215\tLB:Col17_RL1-1'
#
# SRR8367216	FCHC2V5BBXX_L2_wHAXPI032440-15.bam	'@RG\tID:HC2V5BBXX.2\tPL:ILLUMINA\tPU:HC2V5BBXX.2.Col17_RL2-2\tSM:SRR8367216\tLB:Col17_RL2-2'
#
# SRR8367216	FCH7NHMBBXX_L2_wHAXPI032440-15.bam	'@RG\tID:H7NHMBBXX.2\tPL:ILLUMINA\tPU:H7NHMBBXX.2.Col17_RL2-2\tSM:SRR8367216\tLB:Col17_RL2-2'
#
# SRR8367217	FCH7NHMBBXX_L2_wHAXPI032441-16.bam	'@RG\tID:H7NHMBBXX.2\tPL:ILLUMINA\tPU:H7NHMBBXX.2.Col17_RL2-3\tSM:SRR8367217\tLB:Col17_RL2-3'
#
# SRR8367217	FCHC2V5BBXX_L2_wHAXPI032441-16.bam	'@RG\tID:HC2V5BBXX.2\tPL:ILLUMINA\tPU:HC2V5BBXX.2.Col17_RL2-3\tSM:SRR8367217\tLB:Col17_RL2-3'
#
# SRR8367218	FCH7NHMBBXX_L2_wHAXPI032442-17.bam	'@RG\tID:H7NHMBBXX.2\tPL:ILLUMINA\tPU:H7NHMBBXX.2.Col17_RL3-1\tSM:SRR8367218\tLB:Col17_RL3-1'
#
# SRR8367218	FCHC2V5BBXX_L2_wHAXPI032442-17.bam	'@RG\tID:HC2V5BBXX.2\tPL:ILLUMINA\tPU:HC2V5BBXX.2.Col17_RL3-1\tSM:SRR8367218\tLB:Col17_RL3-1'
#
# SRR8367219	FCHC2V5BBXX_L2_wHAXPI032443-18.bam	'@RG\tID:HC2V5BBXX.2\tPL:ILLUMINA\tPU:HC2V5BBXX.2.Col17_RL3-2\tSM:SRR8367219\tLB:Col17_RL3-2'
#
# SRR8367219	FCH7NHMBBXX_L2_wHAXPI032443-18.bam	'@RG\tID:H7NHMBBXX.2\tPL:ILLUMINA\tPU:H7NHMBBXX.2.Col17_RL3-2\tSM:SRR8367219\tLB:Col17_RL3-2'
#
# SRR8367220	FCH7NHMBBXX_L2_wHAXPI032444-19.bam	'@RG\tID:H7NHMBBXX.2\tPL:ILLUMINA\tPU:H7NHMBBXX.2.Col17_RL3-3\tSM:SRR8367220\tLB:Col17_RL3-3'
#
# SRR8367220	FCHC2V5BBXX_L2_wHAXPI032444-19.bam	'@RG\tID:HC2V5BBXX.2\tPL:ILLUMINA\tPU:HC2V5BBXX.2.Col17_RL3-3\tSM:SRR8367220\tLB:Col17_RL3-3'
#
# SRR8367221	FCH7NHMBBXX_L1_wHAXPI032502-29.bam	'@RG\tID:H7NHMBBXX.1\tPL:ILLUMINA\tPU:H7NHMBBXX.1.Col24_RL3-2\tSM:SRR8367221\tLB:Col24_RL3-2'
#
# SRR8367221	FCHC2V5BBXX_L2_wHAXPI032502-29.bam	'@RG\tID:HC2V5BBXX.2\tPL:ILLUMINA\tPU:HC2V5BBXX.2.Col24_RL3-2\tSM:SRR8367221\tLB:Col24_RL3-2'
#
# SRR8367222	FCH7NHMBBXX_L2_wHAXPI032494-21.bam	'@RG\tID:H7NHMBBXX.2\tPL:ILLUMINA\tPU:H7NHMBBXX.2.Col17_RL4-2\tSM:SRR8367222\tLB:Col17_RL4-2'
#
# SRR8367222	FCHC2V5BBXX_L2_wHAXPI032494-21.bam	'@RG\tID:HC2V5BBXX.2\tPL:ILLUMINA\tPU:HC2V5BBXX.2.Col17_RL4-2\tSM:SRR8367222\tLB:Col17_RL4-2'
#
# SRR8367225	FCH7NHMBBXX_L2_wHAXPI032496-23.bam	'@RG\tID:H7NHMBBXX.2\tPL:ILLUMINA\tPU:H7NHMBBXX.2.Col24_RL1-1\tSM:SRR8367225\tLB:Col24_RL1-1'
#
# SRR8367225	FCHC2V5BBXX_L2_wHAXPI032496-23.bam	'@RG\tID:HC2V5BBXX.2\tPL:ILLUMINA\tPU:HC2V5BBXX.2.Col24_RL1-1\tSM:SRR8367225\tLB:Col24_RL1-1'
#
# SRR8367245	FCHC2V5BBXX_L2_wHAXPI032508-36.bam	'@RG\tID:HC2V5BBXX.2\tPL:ILLUMINA\tPU:HC2V5BBXX.2.Col24_RL5-3\tSM:SRR8367245\tLB:Col24_RL5-3'
#
# SRR8367245	FCH7NHMBBXX_L1_wHAXPI032508-36.bam	'@RG\tID:H7NHMBBXX.1\tPL:ILLUMINA\tPU:H7NHMBBXX.1.Col24_RL5-3\tSM:SRR8367245\tLB:Col24_RL5-3'
#
# SRR8367246	FCH7NHMBBXX_L1_wHAXPI032507-35.bam	'@RG\tID:H7NHMBBXX.1\tPL:ILLUMINA\tPU:H7NHMBBXX.1.Col24_RL5-1\tSM:SRR8367246\tLB:Col24_RL5-1'
#
# SRR8367246	FCHC2V5BBXX_L2_wHAXPI032507-35.bam	'@RG\tID:HC2V5BBXX.2\tPL:ILLUMINA\tPU:HC2V5BBXX.2.Col24_RL5-1\tSM:SRR8367246\tLB:Col24_RL5-1'
#
# SRR8367248	FCHC2V5BBXX_L2_wHAXPI032445-20.bam	'@RG\tID:HC2V5BBXX.2\tPL:ILLUMINA\tPU:HC2V5BBXX.2.Col17_RL4-1\tSM:SRR8367248\tLB:Col17_RL4-1'
#
# SRR8367248	FCH7NHMBBXX_L2_wHAXPI032445-20.bam	'@RG\tID:H7NHMBBXX.2\tPL:ILLUMINA\tPU:H7NHMBBXX.2.Col17_RL4-1\tSM:SRR8367248\tLB:Col17_RL4-1'
